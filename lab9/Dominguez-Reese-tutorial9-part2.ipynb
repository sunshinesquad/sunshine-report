# %% [markdown]
# # Tutorial 09 - Kick-Starting your Final Project
#
# Reese Dominguez - 100775764
#
#
# I will partially answer the question "**What proportion of Sunshine Listers are women?**" As we will analyze the dataset for many of the Sunshine Lists over the years, I have decided to just analyze the proportion of women in **2020's Sunshine List**.

# %%
import pandas as pd
import numpy as np

# %%
# Importing the required datasets needed to answer this question
sunshine_2020 = pd.read_csv("sunshine2020.csv")
name_genders = pd.read_csv("wgnd.csv")

# %% [markdown]
# ### Analysis of the World Gender Names Dictionary
#
# There are many first names in the WGND, and all names seem to be lowercased. The version of the WGND I am using (wgnd_2_0_name-gender-langcode.csv) has three fields:
#
# - **Name**: a first name
# - **Langcode**: the short-form code of the language that the name either is in or comes from
# - **Gender**: the associated gender with this name in this language

# %%
name_genders
# Out:
#                   name langcode gender
# 0               "baby"       en      F
# 1              'aisyah       en      F
# 2               'anela       en      F
# 3               'anela       fr      F
# 4         'fiyinfoluwa       en      F
# ...                ...      ...    ...
# 21831038           히카리       ko      F
# 21831039           히토미       ko      F
# 21831040            힘찬       ko      M
# 21831041            凉峰       zh      M
# 21831042            凉翼       zh      M
#
# [21831043 rows x 3 columns]

# %%
# Looking at Russian names, as Russian has an alphabet separate from the Latin one.
# This is to check if names in different languages are lowercased, if the language's
# alphabet/syllabary allows for lowercasing.
name_genders[name_genders['langcode'] == 'ru']
# Out:
#               name langcode gender
# 152335       abram       ru      M
# 189067     aculina       ru      F
# 189246         ada       ru      F
# 192154        adam       ru      M
# 210441       adela       ru      F
# ...            ...      ...    ...
# 21172001       яна       ru      F
# 21172004      ярик       ru      M
# 21172006   ярослав       ru      M
# 21172009  ярослава       ru      F
# 21172012       яша       ru      M
#
# [2735 rows x 3 columns]

# %%
# A name that has multiple genders, depending on the language code
name_genders[name_genders['name'] == 'aubrey']
# Out:
#            name langcode gender
# 1361932  aubrey       af      M
# 1361933  aubrey       ak      M
# 1361934  aubrey       ar      M
# 1361935  aubrey       bn      M
# 1361936  aubrey       ee      M
# 1361937  aubrey       el      M
# 1361938  aubrey       en      M
# 1361939  aubrey       ff      M
# 1361940  aubrey       fr      M
# 1361941  aubrey       gu      M
# 1361942  aubrey       ha      M
# 1361943  aubrey       hi      M
# 1361944  aubrey       kn      M
# 1361945  aubrey       mi      M
# 1361946  aubrey       mr      M
# 1361947  aubrey       mt      M
# 1361948  aubrey       ns      M
# 1361949  aubrey       pa      M
# 1361950  aubrey       rn      M
# 1361951  aubrey       rw      M
# 1361952  aubrey       sa      M
# 1361953  aubrey       se      F
# 1361954  aubrey       sr      M
# 1361955  aubrey       st      M
# 1361956  aubrey       sv      F
# 1361957  aubrey       sw      M
# 1361958  aubrey       ta      M
# 1361959  aubrey       te      M
# 1361960  aubrey       ti      M
# 1361961  aubrey       tl      M
# 1361962  aubrey       tn      M
# 1361963  aubrey       tr      M
# 1361964  aubrey       xh      M
# 1361965  aubrey       zu      M

# %%
# How many entries of each name are there?
name_genders['name'].value_counts()
# Out:
# nina     71
# olga     70
# diana    68
# rita     67
# eva      67
#          ..
# 坡燉        1
# 坡燕        1
# 坡申        1
# 坡石        1
# 凉翼        1
# Name: name, Length: 3505318, dtype: int64

# %%
# Capitalizing names to prepare for merge with Sunshine List
name_genders['name'] = name_genders['name'].str.capitalize()

# %%
# changing gender to int form to find the mode/most common gender
# 0 for M, 1 for F
def change_gender(gender):
    return int(gender == 'F')

name_genders['gender'] = name_genders['gender'].apply(change_gender)

# %%
# checking if capitalize and gender change worked
name_genders.iloc[1337:1337+5]
# Out:
#          name langcode  gender
# 1337   Aabhas       te       0
# 1338  Aabheda       gu       1
# 1339  Aabheda       hi       1
# 1340  Aabheda       kn       1
# 1341  Aabheda       mr       1

# %%
# Removing all non-Latin names from this dataset as the Sunshine List only has Latin names

name_genders['name'] = name_genders['name'].apply(str)

name_genders = name_genders[name_genders['name'].map(lambda x: x.isascii())]

# %%
# This takes a very long time.

wgnd_condensed = name_genders.groupby(['name'])['gender'].agg(pd.Series.mode).to_frame()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11/1298647863.py in <module>
#       1 # This takes a very long time.
#       2
# ----> 3 wgnd_condensed = name_genders.groupby(['name'])['gender'].agg(pd.Series.mode[0]).to_frame()
#
# TypeError: 'function' object is not subscriptable

# %% [markdown]
# This next code snippet will reduce any arrays in the `gender` column to only one value, for ease of calculations. **This will decrease the accuracy of any data we get!**

# %%
def get_first(x):
    if type(x) is np.ndarray:
        return x.flatten()[0]
    else:
        return x

wgnd_condensed['gender'] = wgnd_condensed['gender'].apply(get_first)

# %% [markdown]
# ### Cleanup of the Sunshine LIst
#
# The Sunshine List has been analyzed during the proposal. I set up/clean up the data to prepare for aggregation with the WGND.

# %%
# Change Salary paid and Taxable benefits to be a more easier datatype to sort w/
sunshine_2020["Salary paid"] = sunshine_2020["Salary paid"].replace('[\$,]', '', regex=True).astype(float)
sunshine_2020["Taxable benefits"] = sunshine_2020["Taxable benefits"].replace('[\$,]', '', regex=True).astype(float)

# %%
sunshine_2020
# Out:
#               Sector   Last name  First name  Salary paid  Taxable benefits  \
# 0           Colleges       Aarts       Cheri    113586.57             71.01
# 1           Colleges     Aaslepp        Drew    113685.85            117.26
# 2           Colleges        Abba     Corinne    102214.17            117.36
# 3           Colleges      Abbott       Brian    102855.46            117.36
# 4           Colleges      Abbott    Kathleen    160854.89            326.33
# ...              ...         ...         ...          ...               ...
# 205601  Universities  Zylberberg        Joel    141478.88            727.20
# 205602  Universities       Zylla        Phil    127898.47            231.93
# 205603  Universities     Zytaruk      Nicole    113582.77            231.93
# 205604  Universities      Zytner     Richard    193168.37           1906.08
# 205605  Universities       Zywno  Malgorzata    204615.20           1130.48
#
#                                                  Employer  \
# 0         Fanshawe College Of Applied Arts and Technology
# 1       Humber College Institute Of Technology and Adv...
# 2       George Brown College Of Applied Arts and Techn...
# 3       Conestoga College Institute Of Technology and ...
# 4       George Brown College Of Applied Arts and Techn...
# ...                                                   ...
# 205601                                    York University
# 205602                          McMaster Divinity College
# 205603                                McMaster University
# 205604                               University Of Guelph
# 205605                                 Ryerson University
#
#                                              Job title  Calendar year
# 0                                            Professor           2020
# 1                                            Professor           2020
# 2                                            Librarian           2020
# 3                                            Professor           2020
# 4       Associate Dean, Centre for Continuous Learning           2020
# ...                                                ...            ...
# 205601     Assistant Professor / Canada Research Chair           2020
# 205602                         Vice President Academic           2020
# 205603                              Research Associate           2020
# 205604                                       Professor           2020
# 205605                                       Professor           2020
#
# [205606 rows x 8 columns]

# %%
# So I don't have to type the columns in the next cell

new_cols = list(sunshine_2020.columns)
new_cols.append('gender')

print(new_cols)
# Out:
# ['Sector', 'Last name', 'First name', 'Salary paid', 'Taxable benefits', 'Employer', 'Job title', 'Calendar year', 'gender']

# %%
# Merging the WGND (cleaned up) and 2020's Sunshine List
sunshine_wgnd = pd.merge(sunshine_2020, wgnd_condensed, left_on=['First name'], right_on=['name'])[new_cols]

sunshine_wgnd
# Out:
#                                     Sector    Last name First name  \
# 0                                 Colleges        Aarts      Cheri
# 1                           Crown Agencies         Mara      Cheri
# 2       Government of Ontario — Ministries      Hayward      Cheri
# 3       Government of Ontario — Ministries      Huffman      Cheri
# 4       Government of Ontario — Ministries  Rockefeller      Cheri
# ...                                    ...          ...        ...
# 184122                        Universities       Zuberi    Daniyal
# 184123                        Universities          Zuk    Ireneus
# 184124                        Universities        Zunic    Nikolaj
# 184125                        Universities  Zwarenstein    Merrick
# 184126                        Universities        Zwick     Detlev
#
#         Salary paid  Taxable benefits  \
# 0         113586.57             71.01
# 1         294772.37          10566.38
# 2         167653.20            218.04
# 3         117777.29            148.58
# 4         129912.05            153.72
# ...             ...               ...
# 184122    176340.96            358.74
# 184123    190458.36            292.14
# 184124    157838.40            409.04
# 184125    193254.60             95.60
# 184126    270199.34           1057.56
#
#                                                Employer  \
# 0       Fanshawe College Of Applied Arts and Technology
# 1                   Ontario Cannabis Retail Corporation
# 2                                             Education
# 3               Children, Community and Social Services
# 4                             Ontario Provincial Police
# ...                                                 ...
# 184122                            University Of Toronto
# 184123                               Queen’s University
# 184124                          St. Jerome’s University
# 184125                    University Of Western Ontario
# 184126                                  York University
#
#                                                 Job title  Calendar year  \
# 0                                               Professor           2020
# 1       Chief Commercial Officer / Directrice générale...           2020
# 2       Director, School Board Business Support Branch...           2020
# 3       Business Manager and Comptroller / Chef de la ...           2020
# 4       Law Enforcement Officer / Agente d’exécution d...           2020
# ...                                                   ...            ...
# 184122  Professor of Social Work, Professor of School ...           2020
# 184123                                          Professor           2020
# 184124                                Associate Professor           2020
# 184125                                          Professor           2020
# 184126                         Dean / Associate Professor           2020
#
#         gender
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 184122       0
# 184123       0
# 184124       0
# 184125       0
# 184126       0
#
# [184127 rows x 9 columns]

# %% [markdown]
# Around 20,000 rows were dropped, meaning that there might not be data in the `wgnd_condensed` dataset that's in the `sunshine_2020` dataset. This doesn't seem that bad, but there may be a loss of accuracy.
#
# Now to figure out how many rows have `gender = 1`.

# %%
sunshine_wgnd['gender'].value_counts(normalize=True) * 100
# Out:
# 0    51.732771
# 1    48.267229
# Name: gender, dtype: float64

# %% [markdown]
# It seems that 48.26% of employees in the Sunshine List (that can have an assignable gender based on their name) may be female. This has sparked more interest in this number in particular:
#
# - How many of these women in the list are/may be not white, compared to those who are?
# - What public sectors do they tend to work in?
# - What's the average salary paid of women compared to men?
